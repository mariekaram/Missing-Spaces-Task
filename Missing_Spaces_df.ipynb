# %%
import pandas as pd
import wordsegment
from wordsegment import load, segment
load()

# %%
data = pd.read_csv('missing_spaces.txt', sep=" ", header=None)

# %%
data
# Out:
#                                                       0
# 0                                  BugsBunny(1940-1964)
# 1     Manythousandsofacresofarablefarmlandsurroundth...
# 2     Peoplewhowerebornin,residentsof,orotherwiseclo...
# 3     :UsedbyunitsoftheAmericanExpeditionaryForceatt...
# 4     ChampionHuddle–AlocationnorthofChampionvillage...
# 5     Priorto1933,therewereseparateofficesadminister...
# 6     December9–EugèneGigout,composerandorganist(b.1...
# 7     TheCanadianprovinceofNovaScotiawasaBritishcolo...
# 8     Carboncompositeisakeymaterialintoday'slaunchve...
# 9                                WatchThisSpaceFestival
# 10                                                 Okra
# 11    weighinginformationduringthecourseofdecision-m...
# 12    Fromanavigationperspective,theHavelcanbespliti...
# 13                                  SymphonyNo.2,Op.247
# 14                                               MeMeMe
# 15                                    Modernpreparation
# ...

# %%
seg = []
data[1]=0
for i in data[0].keys():
    data[1][i]=" ".join(str(e) for e in segment(data[0][i]))
# Out:
# /home/marie/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/marie/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data[1].to_csv(r'restored_spaces1.txt',index=False)
